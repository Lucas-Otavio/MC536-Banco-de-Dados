# %%
import requests

url = "https://data.cdc.gov/resource/9mfq-cb36.json"
data = requests.get(url).content
print(data.decode("utf-8"))
# Out:
# [{"submission_date":"2020-02-08T00:00:00.000","state":"AL","tot_cases":"55","conf_cases":"47.0","prob_cases":"8","new_case":"1.0","pnew_case":"0","tot_death":"0","conf_death":"0.0","prob_death":"0","new_death":"0.0","pnew_death":"0","created_at":"2020-02-10T00:00:00.000","consent_cases":"Agree","consent_deaths":"Agree"}
# ,{"submission_date":"2021-02-02T00:00:00.000","state":"IL","tot_cases":"1130917","conf_cases":"1130917.0","prob_cases":"0","new_case":"2304.0","pnew_case":"0","tot_death":"21336","conf_death":"19306.0","prob_death":"2030","new_death":"63.0","pnew_death":"16","created_at":"2021-02-03T14:55:58.025","consent_cases":"Agree","consent_deaths":"Agree"}
# ...

# %%
url = "https://data.cdc.gov/resource/saz5-9hgg.csv"
data = requests.get(url).content
print(data.decode("utf-8"))
# Out:
# "jurisdiction","week_of_allocations","_1st_dose_allocations","_2nd_dose_allocations"
# "Connecticut","2021-06-21T00:00:00.000","54360","54360"
# "Maine","2021-06-21T00:00:00.000","21420","21420"
# "Massachusetts","2021-06-21T00:00:00.000","104580","104580"
# "New Hampshire","2021-06-21T00:00:00.000","21420","21420"
# "Rhode Island","2021-06-21T00:00:00.000","17280","17280"
# "Vermont","2021-06-21T00:00:00.000","11070","11070"
# "New Jersey","2021-06-21T00:00:00.000","132210","132210"
# "New York","2021-06-21T00:00:00.000","167670","167670"
# "New York City","2021-06-21T00:00:00.000","128070","128070"
# "Puerto Rico","2021-06-21T00:00:00.000","52290","52290"
# "U.S. Virgin Islands","2021-06-21T00:00:00.000","3240","3240"
# "Delaware","2021-06-21T00:00:00.000","15210","15210"
# "District of Columbia","2021-06-21T00:00:00.000","11520","11520"
# "Maryland","2021-06-21T00:00:00.000","89370","89370"
# "Pennsylvania","2021-06-21T00:00:00.000","170460","170460"
# ...
